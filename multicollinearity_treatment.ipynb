# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from numpy.linalg import eig

# %%
np.random.seed(73)

# %%
# Create Features
num_players = 200
batting_average = np.random.normal(0.28, 0.05, num_players)
batting_average = np.clip(batting_average, 0.2, 0.4)
AB = np.random.randint(300, 700, num_players)
H = AB * batting_average
Height = np.random.normal(72, 6, num_players)
Wind = np.random.uniform(-1.5, 1.5, num_players)
RBIs = (H *0.5) + (AB * 0.02) + (Height * 0.01) + (Wind * 7) + np.random.randint(0, 10, num_players)

RBIs_rounded = np.round(RBIs)
H_rounded = np.round(H)
AB_rounded = np.round(AB)

# %%
data = pd.DataFrame({
    'AB': AB_rounded,
    'H': H_rounded,
    'Height': Height,
    'Wind': Wind,
    'RBIs': RBIs_rounded
})

# %%
data.head()
# Out:
#     AB      H     Height      Wind   RBIs
# 0  525  164.0  71.688338 -0.152021   98.0
# 1  471  141.0  60.809313  1.458439   91.0
# 2  444  111.0  74.007277 -1.322185   64.0
# 3  494  189.0  71.727770 -0.616022  106.0
# 4  398  118.0  77.992497  1.497708   83.0
